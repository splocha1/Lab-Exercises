# %%
import pandas as pd
import csv
import seaborn as sns

# %%
df = pd.read_csv("AB_NYC_2019 - AB_NYC_2019.csv") 
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#could use a dictionary to count how many airbnb's are in each burough as well as neighborhood 
#find out the price median, mean, etc using df.describe
#can see which appartment has the most reviews per month to see who has the most frequent visiters

# %%
cols = df.columns
sns.heatmap(df[cols].isnull())
# Out:
# <AxesSubplot:>

# %%
df["last_review"] = df["last_review"].fillna("Not Available")
df["reviews_per_month"] = df["reviews_per_month"].fillna("Not Available")
sns.heatmap(df[cols].isnull())
# Out:
# <AxesSubplot:>

# %%
df_2=df.copy()
df_2.last_review = df_2.last_review.str[0:4]
df_2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
places=df["neighbourhood_group"]
place_dict = {}

for i in places:
    if i not in place_dict:
        place_dict[i] = 1
    else:
        place_dict[i]+=1
print(place_dict)
# Out:
# {'Brooklyn': 20104, 'Manhattan': 21661, 'Queens': 5666, 'Staten Island': 373, 'Bronx': 1091}

# %%
import requests
import json

def get_book_info():
    API_key="AIzaSyCdmb6PcXh4Jd03tMnl3NqKeGvHAosASOQ"
    book=input("enter the first word of the book:")
    author=input("enter the author's last name:")
    results=requests.get(f"https://www.googleapis.com/books/v1/volumes?q={book}+inauthor:{author}&key={API_key}")
    print(results)


get_book_info()
